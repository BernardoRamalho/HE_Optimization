# %% [markdown]
# ## Setup

# %%
# Imports
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Data From CSV
small_ring_df = pd.read_csv("../timeCSVs/smallRingDim.csv")
small_ring_df.drop([' decryption', ' plaintext', ' value'], axis=1,inplace=True)

big_ring_df = pd.read_csv("../timeCSVs/bigRingDimTimes.csv")
big_ring_df.drop([' decryption', ' plaintext', ' value'], axis=1,inplace=True)

big_elements_df = pd.read_csv("../timeCSVs/ringDimOptimization.csv")
big_elements_df.drop([' decryption', ' plaintext', ' value'], axis=1,inplace=True)


ring_df = pd.concat([small_ring_df, big_ring_df, big_elements_df], ignore_index=True) 

ring_df.head()
# Out:
#            type   ringDim   setup   encryption   homomorphic   total
# 0  n16-coef-sum         2       7            0             0       7
# 1  n16-coef-sum         2       6            0             0       6
# 2  n16-coef-sum         2      14            0             0      14
# 3  n16-coef-sum         2       7            0             0       7
# 4  n16-coef-sum         2       7            0             0       7

# %%
# Create Dataframes for each number of elements
n16_df = ring_df[ring_df['type'].str.contains('n16')]
n32_df = ring_df[ring_df['type'].str.contains('n32')]
n64_df = ring_df[ring_df['type'].str.contains('n64')]
n128_df = ring_df[ring_df['type'].str.contains('n128')]
n256_df = ring_df[ring_df['type'].str.contains('n256')]
n512_df = ring_df[ring_df['type'].str.contains('n512')]
n1024_df = ring_df[ring_df['type'].str.contains('n1024')]
n2048_df = ring_df[ring_df['type'].str.contains('n2048')]
n4096_df = ring_df[ring_df['type'].str.contains('n4096')]
n8192_df = ring_df[ring_df['type'].str.contains('n8192')]
n10x8192_df = ring_df[ring_df['type'].str.contains('n10x8192')]
n25x8192_df = ring_df[ring_df['type'].str.contains('n25x8192')]
n50x8192_df = ring_df[ring_df['type'].str.contains('n50x8192')]
n100x8192_df = ring_df[ring_df['type'].str.contains('n100x8192')]
n250x8192_df = ring_df[ring_df['type'].str.contains('n250x8192')]
n500x8192_df = ring_df[ring_df['type'].str.contains('n500x8192')]
n1000x8192_df = ring_df[ring_df['type'].str.contains('n1000x8192')]

# %%
# Dataframe for 16 elements averages
n16_mean_df = n16_df.groupby(['type', ' ringDim'], as_index=False).mean()
n16_mean_df.loc[n16_mean_df['type'] == 'n16-coef-inner', 'type'] = 'coef_inner_product'
n16_mean_df.loc[n16_mean_df['type'] == 'n16-coef-sum', 'type'] = 'coef_sum'
n16_mean_df.loc[n16_mean_df['type'] == 'n16-slot-inner', 'type'] = 'slot_inner_product'
n16_mean_df.loc[n16_mean_df['type'] == 'n16-slot-sum', 'type'] = 'slot_sum'

n16_sum_df = n16_mean_df[n16_mean_df['type'].str.contains('sum')]
n16_inner_df = n16_mean_df[n16_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 32 elements averages
n32_mean_df = n32_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n32_mean_df.loc[n32_mean_df['type'] == 'n32-coef-inner', 'type'] = 'coef_inner_product'
n32_mean_df.loc[n32_mean_df['type'] == 'n32-coef-sum', 'type'] = 'coef_sum'
n32_mean_df.loc[n32_mean_df['type'] == 'n32-slot-inner', 'type'] = 'slot_inner_product'
n32_mean_df.loc[n32_mean_df['type'] == 'n32-slot-sum', 'type'] = 'slot_sum'

n32_sum_df = n32_mean_df[n32_mean_df['type'].str.contains('sum')]
n32_inner_df = n32_mean_df[n32_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 64 elements averages
n64_mean_df = n64_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n64_mean_df.loc[n64_mean_df['type'] == 'n64-coef-inner', 'type'] = 'coef_inner_product'
n64_mean_df.loc[n64_mean_df['type'] == 'n64-coef-sum', 'type'] = 'coef_sum'
n64_mean_df.loc[n64_mean_df['type'] == 'n64-slot-inner', 'type'] = 'slot_inner_product'
n64_mean_df.loc[n64_mean_df['type'] == 'n64-slot-sum', 'type'] = 'slot_sum'

n64_sum_df = n64_mean_df[n64_mean_df['type'].str.contains('sum')]
n64_inner_df = n64_mean_df[n64_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 128 elements averages
n128_mean_df = n128_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n128_mean_df.loc[n128_mean_df['type'] == 'n128-coef-inner', 'type'] = 'coef_inner_product'
n128_mean_df.loc[n128_mean_df['type'] == 'n128-coef-sum', 'type'] = 'coef_sum'
n128_mean_df.loc[n128_mean_df['type'] == 'n128-slot-inner', 'type'] = 'slot_inner_product'
n128_mean_df.loc[n128_mean_df['type'] == 'n128-slot-sum', 'type'] = 'slot_sum'

n128_sum_df = n128_mean_df[n128_mean_df['type'].str.contains('sum')]
n128_inner_df = n128_mean_df[n128_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 256 elements averages
n256_mean_df = n256_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n256_mean_df.loc[n256_mean_df['type'] == 'n256-coef-inner', 'type'] = 'coef_inner_product'
n256_mean_df.loc[n256_mean_df['type'] == 'n256-coef-sum', 'type'] = 'coef_sum'
n256_mean_df.loc[n256_mean_df['type'] == 'n256-slot-inner', 'type'] = 'slot_inner_product'
n256_mean_df.loc[n256_mean_df['type'] == 'n256-slot-sum', 'type'] = 'slot_sum'

n256_sum_df = n256_mean_df[n256_mean_df['type'].str.contains('sum')]
n256_inner_df = n256_mean_df[n256_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 512 elements averages
n512_mean_df = n512_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n512_mean_df.loc[n512_mean_df['type'] == 'n512-coef-inner', 'type'] = 'coef_inner_product'
n512_mean_df.loc[n512_mean_df['type'] == 'n512-coef-sum', 'type'] = 'coef_sum'
n512_mean_df.loc[n512_mean_df['type'] == 'n512-slot-inner', 'type'] = 'slot_inner_product'
n512_mean_df.loc[n512_mean_df['type'] == 'n512-slot-sum', 'type'] = 'slot_sum'

n512_sum_df = n512_mean_df[n512_mean_df['type'].str.contains('sum')]
n512_inner_df = n512_mean_df[n512_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 1024 elements averages
n1024_mean_df = n1024_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n1024_mean_df.loc[n1024_mean_df['type'] == 'n1024-coef-inner', 'type'] = 'coef_inner_product'
n1024_mean_df.loc[n1024_mean_df['type'] == 'n1024-coef-sum', 'type'] = 'coef_sum'
n1024_mean_df.loc[n1024_mean_df['type'] == 'n1024-slot-inner', 'type'] = 'slot_inner_product'
n1024_mean_df.loc[n1024_mean_df['type'] == 'n1024-slot-sum', 'type'] = 'slot_sum'

n1024_sum_df = n1024_mean_df[n1024_mean_df['type'].str.contains('sum')]
n1024_inner_df = n1024_mean_df[n1024_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 2048 elements averages
n2048_mean_df = n2048_df.groupby(['type', ' ringDim'], as_index=False)[' total'].mean()
n2048_mean_df.loc[n2048_mean_df['type'] == 'n2048-coef-inner', 'type'] = 'coef_inner_product'
n2048_mean_df.loc[n2048_mean_df['type'] == 'n2048-coef-sum', 'type'] = 'coef_sum'
n2048_mean_df.loc[n2048_mean_df['type'] == 'n2048-slot-inner', 'type'] = 'slot_inner_product'
n2048_mean_df.loc[n2048_mean_df['type'] == 'n2048-slot-sum', 'type'] = 'slot_sum'

n2048_sum_df = n2048_mean_df[n2048_mean_df['type'].str.contains('sum')]
n2048_inner_df = n2048_mean_df[n2048_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 4096 elements averages
n4096_mean_df = n4096_df.groupby(['type', ' ringDim'], as_index=False).mean()

n4096_mean_df.loc[n4096_mean_df['type'] == 'n4096-coef-inner', 'type'] = 'coef_inner_product'
n4096_mean_df.loc[n4096_mean_df['type'] == 'n4096-coef-sum', 'type'] = 'coef_sum'
n4096_mean_df.loc[n4096_mean_df['type'] == 'n4096-slot-inner', 'type'] = 'slot_inner_product'
n4096_mean_df.loc[n4096_mean_df['type'] == 'n4096-slot-sum', 'type'] = 'slot_sum'

n4096_sum_df = n4096_mean_df[n4096_mean_df['type'].str.contains('sum')]
n4096_inner_df = n4096_mean_df[n4096_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 8192 elements averages
n8192_mean_df = n8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n8192_mean_df.loc[n8192_mean_df['type'] == 'n8192-coef-inner', 'type'] = 'coef_inner_product'
n8192_mean_df.loc[n8192_mean_df['type'] == 'n8192-coef-sum', 'type'] = 'coef_sum'
n8192_mean_df.loc[n8192_mean_df['type'] == 'n8192-slot-inner', 'type'] = 'slot_inner_product'
n8192_mean_df.loc[n8192_mean_df['type'] == 'n8192-slot-sum', 'type'] = 'slot_sum'

n8192_sum_df = n8192_mean_df[n8192_mean_df['type'].str.contains('sum')]
n8192_inner_df = n8192_mean_df[n8192_mean_df['type'].str.contains('inner')]

# %%
n8192_mean_df
# Out:
#                   type   ringDim       setup   encryption   homomorphic  \
# 0   coef_inner_product       512    5.480000    22.180000      9.960000
# 1   coef_inner_product      1024    7.030000    21.730000      8.340000
# 2   coef_inner_product      2048   10.110000    22.030000      8.080000
# 3   coef_inner_product      4096   29.620000    28.990000     14.070000
# 4   coef_inner_product      8192   53.120000    29.520000     15.670000
# 5             coef_sum       512    6.160000    11.000000      0.000000
# 6             coef_sum      1024    8.370000    11.050000      0.000000
# 7             coef_sum      2048   14.690000    13.440000      0.140000
# 8             coef_sum      4096   33.100000    14.670000      0.040000
# 9             coef_sum      8192   60.604478    15.149254      0.029851
# 10  slot_inner_product       512   10.310000     6.010000     11.150000
# 11  slot_inner_product      1024   18.030000     6.040000     12.070000
# ...

# %%
# Dataframe for 10x8192 elements averages
n10x8192_mean_df = n10x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n10x8192_mean_df.loc[n10x8192_mean_df['type'] == 'n10x8192-coef-inner', 'type'] = 'coef_inner_product'
n10x8192_mean_df.loc[n10x8192_mean_df['type'] == 'n10x8192-coef-sum', 'type'] = 'coef_sum'
n10x8192_mean_df.loc[n10x8192_mean_df['type'] == 'n10x8192-slot-inner', 'type'] = 'slot_inner_product'
n10x8192_mean_df.loc[n10x8192_mean_df['type'] == 'n10x8192-slot-sum', 'type'] = 'slot_sum'

n10x8192_sum_df = n10x8192_mean_df[n10x8192_mean_df['type'].str.contains('sum')]
n10x8192_inner_df = n10x8192_mean_df[n10x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 25x8192 elements averages
n25x8192_mean_df = n25x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n25x8192_mean_df.loc[n25x8192_mean_df['type'] == 'n25x8192-coef-inner', 'type'] = 'coef_inner_product'
n25x8192_mean_df.loc[n25x8192_mean_df['type'] == 'n25x8192-coef-sum', 'type'] = 'coef_sum'
n25x8192_mean_df.loc[n25x8192_mean_df['type'] == 'n25x8192-slot-inner', 'type'] = 'slot_inner_product'
n25x8192_mean_df.loc[n25x8192_mean_df['type'] == 'n25x8192-slot-sum', 'type'] = 'slot_sum'

n25x8192_sum_df = n25x8192_mean_df[n25x8192_mean_df['type'].str.contains('sum')]
n25x8192_inner_df = n25x8192_mean_df[n25x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 50x8192 elements averages
n50x8192_mean_df = n50x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n50x8192_mean_df.loc[n50x8192_mean_df['type'] == 'n50x8192-coef-inner', 'type'] = 'coef_inner_product'
n50x8192_mean_df.loc[n50x8192_mean_df['type'] == 'n50x8192-coef-sum', 'type'] = 'coef_sum'
n50x8192_mean_df.loc[n50x8192_mean_df['type'] == 'n50x8192-slot-inner', 'type'] = 'slot_inner_product'
n50x8192_mean_df.loc[n50x8192_mean_df['type'] == 'n50x8192-slot-sum', 'type'] = 'slot_sum'

n50x8192_sum_df = n50x8192_mean_df[n50x8192_mean_df['type'].str.contains('sum')]
n50x8192_inner_df = n50x8192_mean_df[n50x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 100x8192 elements averages
n100x8192_mean_df = n100x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n100x8192_mean_df.loc[n100x8192_mean_df['type'] == 'n100x8192-coef-inner', 'type'] = 'coef_inner_product'
n100x8192_mean_df.loc[n100x8192_mean_df['type'] == 'n100x8192-coef-sum', 'type'] = 'coef_sum'
n100x8192_mean_df.loc[n100x8192_mean_df['type'] == 'n100x8192-slot-inner', 'type'] = 'slot_inner_product'
n100x8192_mean_df.loc[n100x8192_mean_df['type'] == 'n100x8192-slot-sum', 'type'] = 'slot_sum'

n100x8192_sum_df = n100x8192_mean_df[n100x8192_mean_df['type'].str.contains('sum')]
n100x8192_inner_df = n100x8192_mean_df[n100x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 250x8192 elements averages
n250x8192_mean_df = n250x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n250x8192_mean_df.loc[n250x8192_mean_df['type'] == 'n250x8192-coef-inner', 'type'] = 'coef_inner_product'
n250x8192_mean_df.loc[n250x8192_mean_df['type'] == 'n250x8192-coef-sum', 'type'] = 'coef_sum'
n250x8192_mean_df.loc[n250x8192_mean_df['type'] == 'n250x8192-slot-inner', 'type'] = 'slot_inner_product'
n250x8192_mean_df.loc[n250x8192_mean_df['type'] == 'n250x8192-slot-sum', 'type'] = 'slot_sum'

n250x8192_sum_df = n250x8192_mean_df[n250x8192_mean_df['type'].str.contains('sum')]
n250x8192_inner_df = n250x8192_mean_df[n250x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 500x8192 elements averages
n500x8192_mean_df = n500x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n500x8192_mean_df.loc[n500x8192_mean_df['type'] == 'n500x8192-coef-inner', 'type'] = 'coef_inner_product'
n500x8192_mean_df.loc[n500x8192_mean_df['type'] == 'n500x8192-coef-sum', 'type'] = 'coef_sum'
n500x8192_mean_df.loc[n500x8192_mean_df['type'] == 'n500x8192-slot-inner', 'type'] = 'slot_inner_product'
n500x8192_mean_df.loc[n500x8192_mean_df['type'] == 'n500x8192-slot-sum', 'type'] = 'slot_sum'

n500x8192_sum_df = n500x8192_mean_df[n500x8192_mean_df['type'].str.contains('sum')]
n500x8192_inner_df = n500x8192_mean_df[n500x8192_mean_df['type'].str.contains('inner')]

# %%
# Dataframe for 1000x8192 elements averages
n1000x8192_mean_df = n1000x8192_df.groupby(['type', ' ringDim'], as_index=False).mean()
n1000x8192_mean_df.loc[n1000x8192_mean_df['type'] == 'n1000x8192-coef-inner', 'type'] = 'coef_inner_product'
n1000x8192_mean_df.loc[n1000x8192_mean_df['type'] == 'n1000x8192-coef-sum', 'type'] = 'coef_sum'
n1000x8192_mean_df.loc[n1000x8192_mean_df['type'] == 'n1000x8192-slot-inner', 'type'] = 'slot_inner_product'
n1000x8192_mean_df.loc[n1000x8192_mean_df['type'] == 'n1000x8192-slot-sum', 'type'] = 'slot_sum'

n1000x8192_sum_df = n1000x8192_mean_df[n1000x8192_mean_df['type'].str.contains('sum')]
n1000x8192_inner_df = n1000x8192_mean_df[n1000x8192_mean_df['type'].str.contains('inner')]

# %%
n1000x8192_mean_df
# Out:
#                   type   ringDim   setup   encryption   homomorphic     total
# 0   coef_inner_product       512    9.00     31718.65      15212.60  46941.38
# 1   coef_inner_product      1024   12.08     28614.90      13769.17  42396.23
# 2   coef_inner_product      2048   16.59     27513.82      13253.83  40784.24
# 3   coef_inner_product      4096   29.35     27345.61      13371.38  40746.34
# 4   coef_inner_product      8192   52.41     27438.09      13725.21  41216.73
# 5             coef_sum       512    9.10     15445.53        551.09  16005.72
# 6             coef_sum      1024   12.84     14052.06        459.57  14524.47
# 7             coef_sum      2048   18.40     13534.68        413.93  13967.01
# 8             coef_sum      4096   33.12     13747.09        398.27  14178.53
# 9             coef_sum      8192   58.36     13808.71        388.71  14256.84
# 10  slot_inner_product       512   21.22      7944.55      15292.24  23258.01
# ...

# %%
# Plot Graphs for 16 elements
# Total time Sum Graph
fig, ax = plt.subplots()

ax.plot(n16_sum_df[n16_sum_df['type'] == 'coef_sum'][' ringDim'], n16_sum_df[n16_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n16_sum_df[n16_sum_df['type'] == 'slot_sum'][' ringDim'], n16_sum_df[n16_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.set_title("Sum Total Time, 16 elements")
ax.grid('on')

plt.xticks([2, 32, 64, 128, 256, 512])
plt.show()

# Total tiem Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n16_inner_df[n16_inner_df['type'] == 'coef_inner_product'][' ringDim'], n16_inner_df[n16_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n16_inner_df[n16_inner_df['type'] == 'slot_inner_product'][' ringDim'], n16_inner_df[n16_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.set_title("Inner Product Total Time, 16 elements")
ax.grid('on')

plt.xticks([2, 32, 64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 32 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n32_sum_df[n32_sum_df['type'] == 'coef_sum'][' ringDim'], n32_sum_df[n32_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n32_sum_df[n32_sum_df['type'] == 'slot_sum'][' ringDim'], n32_sum_df[n32_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 32 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([4, 32, 64, 128, 256, 512])
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n32_inner_df[n32_inner_df['type'] == 'coef_inner_product'][' ringDim'], n32_inner_df[n32_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n32_inner_df[n32_inner_df['type'] == 'slot_inner_product'][' ringDim'], n32_inner_df[n32_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 32 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([4, 32, 64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 64 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n64_sum_df[n64_sum_df['type'] == 'coef_sum'][' ringDim'], n64_sum_df[n64_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n64_sum_df[n64_sum_df['type'] == 'slot_sum'][' ringDim'], n64_sum_df[n64_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 64 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([8, 64, 64, 128, 256, 512])
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n64_inner_df[n64_inner_df['type'] == 'coef_inner_product'][' ringDim'], n64_inner_df[n64_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n64_inner_df[n64_inner_df['type'] == 'slot_inner_product'][' ringDim'], n64_inner_df[n64_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 64 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([8, 64, 64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 128 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n128_sum_df[n128_sum_df['type'] == 'coef_sum'][' ringDim'], n128_sum_df[n128_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n128_sum_df[n128_sum_df['type'] == 'slot_sum'][' ringDim'], n128_sum_df[n128_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 128 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([16, 64, 128, 256, 512])
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n128_inner_df[n128_inner_df['type'] == 'coef_inner_product'][' ringDim'], n128_inner_df[n128_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n128_inner_df[n128_inner_df['type'] == 'slot_inner_product'][' ringDim'], n128_inner_df[n128_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 128 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([16, 64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 256 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n256_sum_df[n256_sum_df['type'] == 'coef_sum'][' ringDim'], n256_sum_df[n256_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n256_sum_df[n256_sum_df['type'] == 'slot_sum'][' ringDim'], n256_sum_df[n256_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 256 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([32, 64, 128, 256, 512])
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n256_inner_df[n256_inner_df['type'] == 'coef_inner_product'][' ringDim'], n256_inner_df[n256_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n256_inner_df[n256_inner_df['type'] == 'slot_inner_product'][' ringDim'], n256_inner_df[n256_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 256 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([32, 64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 512 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n512_sum_df[n512_sum_df['type'] == 'coef_sum'][' ringDim'], n512_sum_df[n512_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n512_sum_df[n512_sum_df['type'] == 'slot_sum'][' ringDim'], n512_sum_df[n512_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 512 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([64, 128, 256, 512])
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n512_inner_df[n512_inner_df['type'] == 'coef_inner_product'][' ringDim'], n512_inner_df[n512_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n512_inner_df[n512_inner_df['type'] == 'slot_inner_product'][' ringDim'], n512_inner_df[n512_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner ProductTotal Time, 512 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([64, 128, 256, 512])
plt.show()

# %%
# Plot Graphs for 1024 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n1024_sum_df[n1024_sum_df['type'] == 'coef_sum'][' ringDim'], n1024_sum_df[n1024_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n1024_sum_df[n1024_sum_df['type'] == 'slot_sum'][' ringDim'], n1024_sum_df[n1024_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 1024 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([128, 256, 512, 1024])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1024_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n1024_inner_df[n1024_inner_df['type'] == 'coef_inner_product'][' ringDim'], n1024_inner_df[n1024_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n1024_inner_df[n1024_inner_df['type'] == 'slot_inner_product'][' ringDim'], n1024_inner_df[n1024_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 1024 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([128, 256, 512, 1024])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1024_inner_total.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 2048 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n2048_sum_df[n2048_sum_df['type'] == 'coef_sum'][' ringDim'], n2048_sum_df[n2048_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n2048_sum_df[n2048_sum_df['type'] == 'slot_sum'][' ringDim'], n2048_sum_df[n2048_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Total Time based on Ring Dimension, 2048 elements")
ax.grid('on')

plt.xticks([256, 512, 1024, 2048])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n2048_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n2048_inner_df[n2048_inner_df['type'] == 'coef_inner_product'][' ringDim'], n2048_inner_df[n2048_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n2048_inner_df[n2048_inner_df['type'] == 'slot_inner_product'][' ringDim'], n2048_inner_df[n2048_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Total Time based on Ring Dimension, 2048 elements")
ax.grid('on')

plt.xticks([256, 512, 1024, 2048])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n2048_inner_total.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 4096 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' ringDim'], n4096_sum_df[n4096_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' ringDim'], n4096_inner_df[n4096_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 4096 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n4096_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' ringDim'], n8192_sum_df[n8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n8192_inner_df[n8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 10x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n10x8192_sum_df[n10x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n10x8192_inner_df[n10x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 10x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n10x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 25x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n25x8192_sum_df[n25x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n25x8192_inner_df[n25x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 25x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n25x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 50x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n50x8192_sum_df[n50x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n50x8192_inner_df[n50x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 50x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n50x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 100x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n100x8192_sum_df[n100x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n100x8192_inner_df[n100x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 100x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n100x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 250x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n250x8192_sum_df[n250x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n250x8192_inner_df[n250x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 250x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n250x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 500x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n500x8192_sum_df[n500x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n500x8192_inner_df[n500x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 500x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n500x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
# Plot Graphs for 1000x8192 elements
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' total'], label='coef_sum')
ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' total'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Total Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_sum_total.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' total'], label='coef_inner_product')
ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' total'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Total Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_inner_total.png", bbox_inches='tight')
plt.show()

### SETUP TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' setup'], label='coef_sum')
ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' setup'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Setup Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_sum_setup.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' setup'], label='coef_inner_product')
ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' setup'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Setup Time, 8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_inner_setup.png", bbox_inches='tight')
plt.show()

### ENCRYPTION TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' encryption'], label='coef_sum')
ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' encryption'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Encryption Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_sum_encryption.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' encryption'], label='coef_inner_product')
ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' encryption'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Encryption Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_inner_encryption.png", bbox_inches='tight')
plt.show()

### HOMOMORPHIC TIME ###
# Plot Sum Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'coef_sum'][' homomorphic'], label='coef_sum')
ax.plot(n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' ringDim'], n1000x8192_sum_df[n1000x8192_sum_df['type'] == 'slot_sum'][' homomorphic'], label='slot_sum')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Sum Homomorphic Operations Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_sum_homomorphic.png", bbox_inches='tight')
plt.show()

# Plot Inner Product Graph
fig, ax = plt.subplots()

ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'coef_inner_product'][' homomorphic'], label='coef_inner_product')
ax.plot(n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' ringDim'], n1000x8192_inner_df[n1000x8192_inner_df['type'] == 'slot_inner_product'][' homomorphic'], label='slot_inner_product')

handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.25, 1))
ax.set_title("Inner Product Homomorphic Operations Time, 1000x8192 elements")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('Ring Dimension')
ax.grid('on')

plt.xticks([512, 1024, 2048, 4096, 8192])
plt.savefig("C:/Users/berna/Desktop/Personal/FEUP/Thesis/Graphs/Line_Graphs/n1000x8192_inner_homomorphic.png", bbox_inches='tight')
plt.show()

# %%
n1000x8192_mean_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\berna\Desktop\Personal\FEUP\Thesis\Project\HE_Optimization\Outcomes\Notebooks\ringDimAnalysis.ipynb Cell 41 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/berna/Desktop/Personal/FEUP/Thesis/Project/HE_Optimization/Outcomes/Notebooks/ringDimAnalysis.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> n1000x8192_mean_df
#
# NameError: name 'n1000x8192_mean_df' is not defined
